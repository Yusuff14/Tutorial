# %% [markdown]
# <a href="https://colab.research.google.com/github/Yusuff14/Tutorial/blob/main/Testing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First Serious Machine Learning Coding on Google Colab

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
import pandas as pd
import numpy as np
arr = [5,6,7,8]
print(type(arr))
# Out:
# <class 'list'>

# %%
from numpy.core.multiarray import ndarray
a = np.array(arr)
print(type(a))
print(a.shape)
print(a.dtype)
print(a.ndim)
# Out:
# <class 'numpy.ndarray'>
# (4,)
# int64
# 1

# %%
import pandas as pd
df = pd.Series(['Monday', "Tuesday", "Wednesday"],['Monday', "Tuesday", "Wednesday"], index = ["a"])
dyl = np.array(["Monday", "Tuesday", "Wednesday"])
d = pd.Series(dyl)
df[:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-9f2181a718e2> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.Series(['Monday', "Tuesday", "Wednesday"],['Monday', "Tuesday", "Wednesday"], index = ["a"])
#       3 dyl = np.array(["Monday", "Tuesday", "Wednesday"])
#       4 d = pd.Series(dyl)
#       5 df[:1]
#
# TypeError: Series.__init__() got multiple values for argument 'index'

# %%
dict_d = {
    'Country': ['Nigeria','Togo'],
    'Capital': ['Abuja','Lome'],
    'Pop': [50, 10]
}

df = pd.DataFrame(dict_d, index=(2,4))
df.iat[1, 2]
# Out:
# 10

# %%
df.Pop.sum()
# Out:
# 60

# %%
df.describe()
# Out:
#              Pop
# count   2.000000
# mean   30.000000
# std    28.284271
# min    10.000000
# 25%    20.000000
# 50%    30.000000
# 75%    40.000000
# max    50.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Pop'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
# ...

# %%
df.isnull().sum()
# Out:
# Country    0
# Capital    0
# Pop        0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Country    2
# Capital    2
# Pop        2
# dtype: int64
